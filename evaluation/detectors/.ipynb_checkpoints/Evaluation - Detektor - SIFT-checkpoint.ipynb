# %% [markdown]
# # Evaluierung des TILDE Detektors

# %%
import numpy as np
import pandas as pd
import cv2
import os
import pickle
from typing import List, Tuple, Dict, Any
import eval_repeatability as er
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %% [markdown]
# ### Lade Daten

# %%
detector_name='tilde'

# %%
with open('outputs/repeatability_{}.pkl'.format(detector_name), 'rb') as dst:
    data = pickle.load(dst, encoding='utf-8')

# %% [markdown]
# ### Kollektion: Webcam
# ### Set: Chamonix

# %% [markdown]
# #### Anzahl gefundener Keypunkte

# %%
set_name='chamonix'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.gca().axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.gca().axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### Chamonix: Wiederholbare Keypunkte

# %% [markdown]
# Prozentualer Anteil an Keypunkten, die bis zum i-ten Bild wiederholbar sind, das heißt in allen Bildern bis zum zum i-ten Bild gefunden wurden. Die maximale Distanz der Positionen eines Keypunktpaares darf $\epsilon$ Pixel nicht überschreiten.

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();

# %%
# TODO
# Zeige die weiderholbaren Keypunkte aus dem ersten und dem letzten 
# Bild an - nebeneinander oder übereinander.

# %% [markdown]
# ### Set Courbevoie

# %%
set_name='courbevoie'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### Courbevoie: Wiederholbare Keypunkte

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();

# %% [markdown]
# ### Set Frankfurt

# %%
set_name='frankfurt'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### Frankfurt: Wiederholbare Keypunkte

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();

# %% [markdown]
# ### Set Mexico

# %%
set_name='mexico'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### Mexico: Wiederholbare Keypunkte

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();

# %% [markdown]
# ### Set Panorama

# %%
set_name='panorama'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### Panorama: Wiederholbare Keypunkte

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();

# %% [markdown]
# ### Set StLouis

# %%
set_name='stlouis'
data_set = data['webcam'][set_name]
num_kpts_per_image = data_set['num_kpts_per_image']
avg = data_set['num_kpts_per_image_avg']
std = data_set['num_kpts_per_image_std']

# %%
plt.rcParams['figure.figsize'] = [16, 9]
plt.axhline(y=avg+std, color='orange', linestyle=':', label='sigma +')
plt.axhline(y=avg, color='red', label='mean {}'.format(avg))
plt.axhline(y=avg-std, color='orange', linestyle=':', label='sigma -')
plt.bar(np.arange(len(num_kpts_per_image)), num_kpts_per_image);
plt.title('{} - {}'.format(set_name, detector_name))
plt.xlabel('Das i-te Bild');
plt.ylabel('Anzahl gefundener Keypunkte in Bild i');
plt.legend();

# %% [markdown]
# ### StLouis: Wiederholbare Keypunkte

# %%
plt.rcParams['figure.figsize'] = [16, 9]
epsilons = list(data['webcam'][set_name]['epsilon'].keys())
for eps in epsilons:
    y = data['webcam'][set_name]['epsilon'][eps]['cum_repeatable_kpts']
    y = y / y[0]
    x = len(y)
    
    plt.plot(np.arange(len(y)), y, label='Epsilon={}'.format(eps))
plt.title('{} - {}: Wiederholbarkeit für Epsilon'.format(detector_name, set_name))
plt.xlabel('Anzahl Bilder')
plt.ylabel('Prozent wiederholbare Keypunkte')
plt.legend();
